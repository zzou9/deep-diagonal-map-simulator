# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = "/Users/zou/Documents/brown/codes/pentagram/out/energy_coords/e0_1_-1_1.csv"
df = pd.read_csv(url)

# %%
x_coord = df['e0']
y_coord = df['e0_prime']

# plot the figure
plt.figure(figsize=(10, 5))
plt.scatter(x_coord, y_coord, marker='o', s=5)

# fit linear line
coeffs = np.polyfit(x_coord, y_coord, 1)  # 1 indicates a linear fit
linear_fit = np.poly1d(coeffs)

# Calculate slope and intercept
# a = coeffs[2]
b = coeffs[1]
c = coeffs[0]

# Create the equation text
equation_text = f'y = {b:.2f}x + {c:.2f}'

# # Plot the linear approximation
# plt.plot(x_coord, linear_fit(x_coord), color='gray', linewidth=1, label='Linear Fit')

# # Add the equation text to the plot
# plt.text(-0.7, -1.75, equation_text, fontsize=12, color='black')

plt.xlabel('e0 value')
plt.ylabel("e'0 value")
plt.title('?')
plt.grid(True)
plt.show()
